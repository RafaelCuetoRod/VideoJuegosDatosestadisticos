# %% [markdown]
# # **Llamar librerias**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2 as cv
# %matplotlib inline

# %% [markdown]
# # **Escrbir palabras u operaciones matemáticas**

# %%
print("glword")
# Out:
# glword

# %%
print(2+2)
# Out:
# 4

# %%
print("2+2")
# Out:
# 2+2

# %%
print("el resultado de 2 más 2 es igual a", 2+2)
# Out:
# el resultado de 2 más 2 es igual a 4

# %%
x=90
y=np.pi

# %%
print(x)
# Out:
# 90

# %%
print(y)
# Out:
# 3.141592653589793

# %%
print(x,y)
print(x,y,x+y)
# Out:
# 90 3.141592653589793
# 90 3.141592653589793 93.1415926535898

# %%
x+y
# Out:
# 93.1415926535898

# %%
z="a"
w="b"

# %%
z+w
# Out:
# 'ab'

# %%
np.cos(x)
# Out:
# -0.4480736161291701

# %%
np.cos(y)
# Out:
# -1.0

# %%
np.round(np.cos(np.deg2rad(x)),17)
# Out:
# 6e-17

# %%
np.cos(np.radians(180))
# Out:
# -1.0

# %%
np.round((134.34345),2)
# Out:
# 134.34

# %% [markdown]
# # **Vamos a añadir una imagen, en este ejemplo una casa**

# %%
imagencasa=cv.imread("casa.jpg")

# %%
imagencasa

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba4402ba-b83c-4213-9415-baae366a365c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba4402ba-b83c-4213-9415-baae366a365c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving casa.jpg to casa.jpg

# %%
# !ls
# Out:
# casa.jpg  sample_data

# %%
imagen=cv.imread("casa.jpg")

# %%
print(imagen)
# Out:
# [[[155 108 110]
#   [155 108 110]
#   [155 108 110]
#   ...
#   [160 108  95]
#   [160 108  95]
#   [160 108  95]]
#
#  [[156 109 111]
#   [156 109 111]
#   [156 109 111]
#   ...
#   [161 109  96]
#   [160 108  95]
#   [160 108  95]]
#
#  [[156 109 111]
#   [156 109 111]
#   [156 109 111]
#   ...
#   [161 109  96]
#   [161 109  96]
#   [161 109  96]]
#
#  ...
#
#  [[179 162 175]
#   [188 171 184]
#   [170 153 166]
#   ...
#   [207 180 176]
#   [201 174 170]
#   [198 171 167]]
#
#  [[181 163 176]
#   [174 156 169]
#   [186 168 181]
#   ...
#   [176 151 147]
#   [200 175 171]
#   [196 171 167]]
#
#  [[174 156 169]
#   [180 162 175]
#   [174 156 169]
#   ...
#   [199 174 170]
#   [199 174 170]
#   [204 179 175]]]

# %%
plt.imshow(imagen)

# %%
plt.figure(figsize=(18,5))
plt.imshow(imagen)
plt.show()

# %%
imagen2=cv.cvtColor(imagen,cv.COLOR_BGR2RGB)

# %%
plt.imshow(imagen2)

# %%
imagen2
# Out:
# array([[[110, 108, 155],
#         [110, 108, 155],
#         [110, 108, 155],
#         ...,
#         [ 95, 108, 160],
#         [ 95, 108, 160],
#         [ 95, 108, 160]],
#
#        [[111, 109, 156],
#         [111, 109, 156],
#         [111, 109, 156],
#         ...,
#         [ 96, 109, 161],
#         [ 95, 108, 160],
#         [ 95, 108, 160]],
#
#        [[111, 109, 156],
#         [111, 109, 156],
#         [111, 109, 156],
#         ...,
#         [ 96, 109, 161],
#         [ 96, 109, 161],
#         [ 96, 109, 161]],
#
#        ...,
#
#        [[175, 162, 179],
#         [184, 171, 188],
#         [166, 153, 170],
#         ...,
#         [176, 180, 207],
#         [170, 174, 201],
#         [167, 171, 198]],
#
#        [[176, 163, 181],
#         [169, 156, 174],
#         [181, 168, 186],
#         ...,
#         [147, 151, 176],
#         [171, 175, 200],
#         [167, 171, 196]],
#
#        [[169, 156, 174],
#         [175, 162, 180],
#         [169, 156, 174],
# ...

# %%
imagen3=cv.cvtColor(imagen, cv.COLOR_BGR2GRAY)

# %%
imagen3
# Out:
# array([[114, 114, 114, ..., 110, 110, 110],
#        [115, 115, 115, ..., 111, 110, 110],
#        [115, 115, 115, ..., 111, 111, 111],
#        ...,
#        [168, 177, 159, ..., 182, 176, 173],
#        [169, 162, 174, ..., 153, 177, 173],
#        [162, 168, 162, ..., 176, 176, 181]], dtype=uint8)

# %%
plt.imshow(imagen3)

# %%
imagen[0]
# Out:
# array([[155, 108, 110],
#        [155, 108, 110],
#        [155, 108, 110],
#        ...,
#        [160, 108,  95],
#        [160, 108,  95],
#        [160, 108,  95]], dtype=uint8)

# %%
imagen2[0]
# Out:
# array([[110, 108, 155],
#        [110, 108, 155],
#        [110, 108, 155],
#        ...,
#        [ 95, 108, 160],
#        [ 95, 108, 160],
#        [ 95, 108, 160]], dtype=uint8)

# %%
imagen3[0]
# Out:
# array([114, 114, 114, 114, 114, 114, 114, 114, 115, 115, 115, 115, 115,
#        116, 116, 116, 115, 115, 115, 115, 115, 115, 115, 115, 115, 115,
#        115, 115, 115, 115, 115, 115, 114, 115, 115, 115, 115, 115, 115,
#        114, 115, 115, 115, 115, 115, 114, 114, 114, 114, 114, 115, 115,
#        115, 115, 116, 116, 115, 115, 115, 115, 115, 115, 116, 116, 115,
#        115, 115, 115, 115, 115, 115, 115, 114, 114, 114, 115, 115, 115,
#        115, 115, 115, 115, 116, 116, 116, 116, 116, 116, 116, 116, 116,
#        116, 116, 116, 117, 117, 115, 115, 115, 115, 115, 116, 116, 116,
#        116, 116, 116, 116, 116, 116, 116, 116, 115, 115, 115, 115, 115,
#        115, 115, 115, 116, 116, 116, 116, 116, 116, 116, 116, 117, 117,
#        117, 117, 117, 117, 117, 118, 117, 117, 117, 117, 117, 117, 117,
#        117, 117, 117, 117, 117, 117, 117, 118, 118, 118, 118, 118, 118,
#        118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 119,
# ...

# %%
r,g,b=cv.split(imagen2)

# %%
r
# Out:
# array([[110, 110, 110, ...,  95,  95,  95],
#        [111, 111, 111, ...,  96,  95,  95],
#        [111, 111, 111, ...,  96,  96,  96],
#        ...,
#        [175, 184, 166, ..., 176, 170, 167],
#        [176, 169, 181, ..., 147, 171, 167],
#        [169, 175, 169, ..., 170, 170, 175]], dtype=uint8)

# %%
g
# Out:
# array([[108, 108, 108, ..., 108, 108, 108],
#        [109, 109, 109, ..., 109, 108, 108],
#        [109, 109, 109, ..., 109, 109, 109],
#        ...,
#        [162, 171, 153, ..., 180, 174, 171],
#        [163, 156, 168, ..., 151, 175, 171],
#        [156, 162, 156, ..., 174, 174, 179]], dtype=uint8)

# %%
b
# Out:
# array([[155, 155, 155, ..., 160, 160, 160],
#        [156, 156, 156, ..., 161, 160, 160],
#        [156, 156, 156, ..., 161, 161, 161],
#        ...,
#        [179, 188, 170, ..., 207, 201, 198],
#        [181, 174, 186, ..., 176, 200, 196],
#        [174, 180, 174, ..., 199, 199, 204]], dtype=uint8)

# %%
np.shape(r)
# Out:
# (654, 960)

# %%
np.shape(g)
# Out:
# (654, 960)

# %%
np.shape(b)
# Out:
# (654, 960)

# %% [markdown]
# # **Mostrar la imagen en una fila y tres columnas**

# %%
plt.figure(figsize=(28,19))
plt.subplot(131)
im=plt.imshow(b,cmap="Blues")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.subplot(132)
im=plt.imshow(r,cmap="Reds")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.subplot(133)
im=plt.imshow(g,cmap="Greens")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.show()

# %% [markdown]
# # **Mostrar la imagen en una columna y en tres filas**

# %%
plt.figure(figsize=(18,9))
plt.subplot(311)
im=plt.imshow(b,cmap="Blues")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.subplot(312)
im=plt.imshow(r,cmap="Reds")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.subplot(313)
im=plt.imshow(g,cmap="Greens")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.show()

# %% [markdown]
# # **Histograma de intensidad de colores de la imagen (Azul, Verde, Rojo)**

# %%
plt.figure(figsize=(8,6))
plt.hist(b.ravel(),bins=256,range=(0,256),color='b',label='blue')
plt.hist(g.ravel(),bins=256,range=(0,256),color='g',label='green')
plt.hist(r.ravel(),bins=256,range=(0,256),color='r',label='red')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(b.ravel(),bins=256,range=(0,256),color='b',label='blue',alpha=0.5)
plt.hist(g.ravel(),bins=256,range=(0,256),color='g',label='green',alpha=0.5)
plt.hist(r.ravel(),bins=256,range=(0,256),color='r',label='red',alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# La distribución de intensidad de color azul es unimodal sesgada hacia la derecha. La mayoria de las intencidades esta asociada a 191 (media si tomamos el grado de intensidad entre 130 y 250, y se logra visualisar que la moda es 196), a demas el 50% de los pixceles (313920) son menores a 178. sin embargo considerando la desviacion estandar (60) las intensidades más probables estan en el intervalo (131,251)

# %% [markdown]
# # **Datos estadisticos y grafico por color de la imagen**

# %% [markdown]
# # **Azul (b1)**

# %%
b1=b.ravel()

# %%
b1
# Out:
# array([155, 155, 155, ..., 199, 199, 204], dtype=uint8)

# %%
#Cantidad de pixceles
np.shape(b1)
# Out:
# (627840,)

# %%
plt.figure(figsize=(8,6))
plt.hist(b1,bins=256,range=(0,256),color='b',label='blue')
plt.legend()
plt.show()

# %%
print("la media es",np.mean(b1))
# Out:
# la media es 154.1599738786952

# %%
print("la media entre 130 y 250 es",np.round(np.mean(b1[(b1>130)&(b1<250)])))
# Out:
# la media entre 130 y 250 es 191.0

# %%
print("la mediana es",np.round(np.median(b1)))
# Out:
# la mediana es 178.0

# %%
print("la desviación estandar es",np.round(np.std(b1)))
# Out:
# la desviación estandar es 60.0

# %%
import scipy

# %%
from scipy import stats

# %%
print("la moda es",stats.mode(b1))
# Out:
# la moda es ModeResult(mode=array([196], dtype=uint8), count=array([8005]))

# %%
print("la kurtosis es",(stats.kurtosis(b1)))
# Out:
# la kurtosis es -0.5670256616480609

# %%
stats.skew(b1)
# Out:
# -0.7484166354895374

# %% [markdown]
# # **Rojo (r1)**

# %%
r1=r.ravel()

# %%
r1
# Out:
# array([110, 110, 110, ..., 170, 170, 175], dtype=uint8)

# %%
#Cantidad de pixceles
np.shape(r1)
# Out:
# (627840,)

# %%
plt.figure(figsize=(8,6))
plt.hist(r1,bins=256,range=(0,256),color='r',label='red')
plt.legend()
plt.show()

# %% [markdown]
# La distribución de intensidad de color roja es unimodal con cierto sesgo hacia la derecha. La mayoria de las intencidades esta asociada a 146 (media), a demas el 50% de los pixceles (313920) son menores a 151. sin embargo considerando la desviacion estandar (56) las intensidades más probables estan en el intervalo (145,200)

# %%
print("la media es",np.round(np.mean(r1)))
# Out:
# la media es 146.0

# %%
print("la mediana es",np.round(np.median(r1)))
# Out:
# la mediana es 151.0

# %%
print("la desviación estandar",np.round(np.std(r1)))
# Out:
# la desviación estandar 56.0

# %%
print("la moda es",stats.mode(r1))
# Out:
# la moda es ModeResult(mode=array([255], dtype=uint8), count=array([7060]))

# %%
print("la kurtosis es",stats.kurtosis(r1))
# Out:
# la kurtosis es -0.3990756107950828

# %%
stats.skew(r1)
# Out:
# -0.32609062548045475

# %% [markdown]
# # **Verde (g1)**

# %%
g1=g.ravel()

# %%
g1
# Out:
# array([108, 108, 108, ..., 174, 174, 179], dtype=uint8)

# %%
#Cantidad de los pixceles
np.shape(g1)
# Out:
# (627840,)

# %%
plt.figure(figsize=(8,6))
plt.hist(g1,bins=256,range=(0,256),color='g',label='gree')
plt.legend()
plt.show()

# %% [markdown]
# La distribución de intensidad de color verde es unimodal con cierto sesgo hacia la derecha. La mayoria de las intencidades esta asociada a 137 (media), a demas el 50% de los pixceles (313920) son menores a 148. sin embargo considerando la desviacion estandar (55) las intensidades más probables estan en el intervalo (115,210)

# %%
print("la media es",np.round(np.mean(g1)))
# Out:
# la media es 138.0

# %%
print("la mediana es",np.round(np.median(g1)))
# Out:
# la mediana es 148.0

# %%
print("la desviación estandar es",np.round(np.std(g1),4))
# Out:
# la desviación estandar es 55.1629

# %%
print("la moda es",stats.mode(g1))
# Out:
# la moda es ModeResult(mode=array([152], dtype=uint8), count=array([5354]))

# %%
print("la kurtosis es",stats.kurtosis(g1))
# Out:
# la kurtosis es -0.45533160739083467

# %%
stats.skew(g1)
# Out:
# -0.5510268185361469

# %% [markdown]
# # **Tabla con los datos estadisticos de cada histograma por color**

# %%
Estadisticos=pd.DataFrame({"Azul(b1)":[(np.round(np.mean(b1),3)),(np.round(np.median(b1),3)),(np.round(np.std(b1),3)),(np.round(stats.kurtosis(b1),3)),(np.round(stats.skew(b1),3))],"Rojo(r1)":[(np.round(np.mean(r1),3)),(np.round(np.median(r1),3)),(np.round(np.std(r1),3)),(np.round(stats.kurtosis(r1),3)),(np.round(stats.skew(r1),3))],"Verde(g1)":[(np.round(np.mean(g1),3)),(np.round(np.median(g1),3)),(np.round(np.std(g1),3)),(np.round(stats.kurtosis(g1),3)),(np.round(stats.skew(g1),3))]},index=["MEDIA","MEDIANA","DESVIACIÓN ESTANDAR","KURTOSIS","SKEW"])
Estadisticos
# Out:
#                      Azul(b1)  Rojo(r1)  Verde(g1)
# MEDIA                 154.160   146.203    137.502
# MEDIANA               178.000   151.000    148.000
# DESVIACIÓN ESTANDAR    59.864    55.885     55.163
# KURTOSIS               -0.567    -0.399     -0.455
# SKEW                   -0.748    -0.326     -0.551
